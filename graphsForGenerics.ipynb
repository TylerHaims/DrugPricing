# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd


df_drug_prices = pd.read_csv('Historical Drug Pricing Data.csv')
df_drug_prices
generic_df = df_drug_prices[df_drug_prices['HCPCS_Code']== 'J9035']
generic_df = generic_df.sort_values(by='year')
generic_df = generic_df.sort_values(by='month')
grouped = generic_df.groupby([generic_df['year'], generic_df['month']])
meanWAC = grouped['WAC per Unit'].mean()
#print(grouped['WAC per unit'].mean())
# for name, group_data in grouped:
    # print("THIS IS THE NAME " + str(name))
    # print(group_data)

        


# grouped2 = grouped1.groupby('month')
# df_drug_prices
# mean_WAC = grouped1['WAC per Unit'].mean()

# print(mean_WAC)


df_drug_prices['unique_manu'] = df_drug_prices['Manufacturer'].str.replace(' ', '')
df_drug_prices['unique_manu'] = df_drug_prices['Manufacturer'].str.replace('"', '')
df_drug_prices['unique_manu'] = df_drug_prices['Manufacturer'].str.replace("'", '')
df_drug_prices['unique_manu'] = df_drug_prices['Manufacturer'].str[:4]

df_drug_prices['unique_manu'] = df_drug_prices['Manufacturer'].str[:4]
df_drug_prices.to_csv('adjust_manu.csv', index = False)
# Out:
# /var/folders/bm/1w41d91d62g66z6j74mqdrl40000gn/T/ipykernel_16614/3737923148.py:6: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_drug_prices = pd.read_csv('Historical Drug Pricing Data.csv')
